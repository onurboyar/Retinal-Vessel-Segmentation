# %% [markdown]
# ## Mount Drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## Imports

# %%
from matplotlib import pyplot as plt
import os, shutil
import random
import cv2
from __future__ import print_function
import pickle
import time
import glob
import numpy as np
import keras
from keras.models import Model
from keras.layers import Input, merge, Convolution2D, MaxPooling2D, UpSampling2D
from keras.optimizers import Adam
from keras.optimizers import SGD
from keras.callbacks import ModelCheckpoint, LearningRateScheduler
from keras import backend as keras
from keras.layers import Dropout
from sklearn.externals import joblib
import argparse
from keras.callbacks import *
import sys
import theano
import theano.tensor as T
from keras import initializers
from keras.layers import BatchNormalization
import copy
import tensorflow as tf
from keras.models import *
from keras.layers import *
from keras.optimizers import *
from tensorflow.keras.models import load_model as load_initial_model
from keras.preprocessing.image import ImageDataGenerator
from keras.losses import binary_crossentropy
import gc
from keras.layers import Conv2D, MaxPooling2D, UpSampling2D, Dropout
from keras.layers import concatenate, Conv2DTranspose, BatchNormalization
from keras import backend as K
from tensorflow.keras.metrics import AUC

# %% [markdown]
# ## Merge Augmentations

# %%
def merge_augmentations(augment_dir, output_dir, list_of_aug_files):
  '''
    - augment_dir         (string)   : The path which has subfolders that are augmentation folders.
    - output_dir          (string)   : The path you want to put all augmentations.
    - list_of_aug_files   (list)     : List of names which contains augmentations.
  '''
  os.mkdir(output_dir + '/images')
  os.mkdir(output_dir + '/labels')

  for folder in list_of_aug_files:
    if folder != 'train':
      for file in sorted(os.listdir(augment_dir + '/' + folder + '/images')):
        shutil.copy(augment_dir + '/' + folder + '/images/' + file, output_dir + '/images/' + folder + '_' + file.split("_")[-1].split('.')[0] + '.png')
        shutil.copy(augment_dir + '/' + folder + '/labels/' + file, output_dir + '/labels/' + folder + '_' + file.split("_")[-1].split('.')[0] + '.png')
    else:
      for file in sorted(os.listdir(augment_dir + '/' + folder + '/images')):
        shutil.copy(augment_dir + '/' + folder + '/images/' + file, output_dir + '/images/' + file.split("_")[-1].split('.')[0] + '.png')
        shutil.copy(augment_dir + '/' + folder + '/labels/' + file, output_dir + '/labels/' + file.split("_")[-1].split('.')[0] + '.png')
    

    print(folder + ' folder has been merged...')
    print('Number of images in output: ' + str(len(os.listdir(output_dir + '/images'))))
 

  print('Merging is done successfully!')

# %% [markdown]
# ## Handcrafted Metrics

# %%
def dice_coef(y_true, y_pred):
  smooth = 0.0
  y_true_f = keras.flatten(y_true)
  y_pred_f = keras.flatten(y_pred)
  intersection = keras.sum(y_true_f * y_pred_f)
  return (2. * intersection + smooth) / (keras.sum(y_true_f) + keras.sum(y_pred_f) + smooth)

def jacard(y_true, y_pred):

  y_true_f = keras.flatten(y_true)
  y_pred_f = keras.flatten(y_pred)
  intersection = keras.sum ( y_true_f * y_pred_f)
  union = keras.sum ( y_true_f + y_pred_f - y_true_f * y_pred_f)

  return intersection/union

# %% [markdown]
# ## Generators

# %%
def adjustData(img,mask,flag_multi_class,num_class):
  if(flag_multi_class):
    img = img / 255
    mask = mask[:,:,:,0] if(len(mask.shape) == 4) else mask[:,:,0]
    new_mask = np.zeros(mask.shape + (num_class,))
    for i in range(num_class):
        #for one pixel in the image, find the class in mask and convert it into one-hot vector
        #index = np.where(mask == i)
        #index_mask = (index[0],index[1],index[2],np.zeros(len(index[0]),dtype = np.int64) + i) if (len(mask.shape) == 4) else (index[0],index[1],np.zeros(len(index[0]),dtype = np.int64) + i)
        #new_mask[index_mask] = 1
        new_mask[mask == i,i] = 1
    new_mask = np.reshape(new_mask,(new_mask.shape[0],new_mask.shape[1]*new_mask.shape[2],new_mask.shape[3])) if flag_multi_class else np.reshape(new_mask,(new_mask.shape[0]*new_mask.shape[1],new_mask.shape[2]))
    mask = new_mask
  elif (np.max(img) > 1):
    img = img / 255
    mask = mask /255
    mask[mask > 0.5] = 1
    mask[mask <= 0.5] = 0
  return (img,mask)

# %%
def trainGenerator(batch_size,train_path,image_folder,mask_folder,aug_dict,image_color_mode = "grayscale",
                    mask_color_mode = "grayscale",image_save_prefix  = "image",mask_save_prefix  = "mask",
                    flag_multi_class = False,num_class = 2,save_to_dir = None,target_size = (608,704),seed = 1):
  image_datagen = ImageDataGenerator(**aug_dict)
  mask_datagen = ImageDataGenerator(**aug_dict)
  image_generator = image_datagen.flow_from_directory(
      train_path,
      classes = [image_folder],
      class_mode = None,
      color_mode = image_color_mode,
      target_size = target_size,
      batch_size = batch_size,
      save_to_dir = save_to_dir,
      save_prefix  = image_save_prefix,
      seed = seed)
  mask_generator = mask_datagen.flow_from_directory(
      train_path,
      classes = [mask_folder],
      class_mode = None,
      color_mode = mask_color_mode,
      target_size = target_size,
      batch_size = batch_size,
      save_to_dir = save_to_dir,
      save_prefix  = mask_save_prefix,
      seed = seed)
  train_generator = zip(image_generator, mask_generator)
  for (img,mask) in train_generator:
    img,mask = adjustData(img,mask,flag_multi_class,num_class)
    yield (img,mask)

# %%
def testGenerator2(batch_size,test_path,image_folder,mask_folder,aug_dict,image_color_mode = "grayscale",
                    mask_color_mode = "grayscale",image_save_prefix  = "image",mask_save_prefix  = "mask",
                    flag_multi_class = False,num_class = 2,save_to_dir = None,target_size = (608,704),seed = 1):
  image_datagen = ImageDataGenerator(**aug_dict)
  mask_datagen = ImageDataGenerator(**aug_dict)
  image_generator = image_datagen.flow_from_directory(
      test_path,
      classes = [image_folder],
      class_mode = None,
      color_mode = image_color_mode,
      target_size = target_size,
      batch_size = batch_size,
      save_to_dir = save_to_dir,
      save_prefix  = image_save_prefix,
      seed = seed)
  mask_generator = mask_datagen.flow_from_directory(
      test_path,
      classes = [mask_folder],
      class_mode = None,
      color_mode = mask_color_mode,
      target_size = target_size,
      batch_size = batch_size,
      save_to_dir = save_to_dir,
      save_prefix  = mask_save_prefix,
      seed = seed)
  test_generator = zip(image_generator, mask_generator)
  for (img,mask) in test_generator:
    img,mask = adjustData(img,mask,flag_multi_class,num_class)
    yield (img,mask)

# %% [markdown]
# ## Model

# %%
def fire_module(x, fire_id, squeeze=16, expand=64):
    f_name = "fire{0}/{1}"
    channel_axis = 1 if K.image_data_format() == 'channels_first' else -1

    x = Conv2D(squeeze, (1, 1), activation='relu', padding='same', name=f_name.format(fire_id, "squeeze1x1"))(x)
    x = BatchNormalization(axis=channel_axis)(x)

    left = Conv2D(expand, (1, 1), activation='relu', padding='same', name=f_name.format(fire_id, "expand1x1"))(x)
    right = Conv2D(expand, (3, 3), activation='relu', padding='same', name=f_name.format(fire_id, "expand3x3"))(x)
    x = concatenate([left, right], axis=channel_axis, name=f_name.format(fire_id, "concat"))
    return x

def SqueezeUNet(inputs, num_classes=None, deconv_ksize=3, dropout=0.5, activation='sigmoid'):
    """SqueezeUNet is a implementation based in SqueezeNetv1.1 and unet for semantic segmentation
    :param inputs: input layer.
    :param num_classes: number of classes.
    :param deconv_ksize: (width and height) or integer of the 2D deconvolution window.
    :param dropout: dropout rate
    :param activation: type of activation at the top layer.
    :returns: SqueezeUNet model
    """
    channel_axis = 1 if K.image_data_format() == 'channels_first' else -1
    if num_classes is None:
        num_classes = K.int_shape(inputs)[channel_axis]

    x01 = Conv2D(64, (3, 3), strides=(2, 2), padding='same', activation='relu', name='conv1')(inputs)
    x02 = MaxPooling2D(pool_size=(3, 3), strides=(2, 2), name='pool1', padding='same')(x01)

    x03 = fire_module(x02, fire_id=2, squeeze=16, expand=64)
    x04 = fire_module(x03, fire_id=3, squeeze=16, expand=64)
    x05 = MaxPooling2D(pool_size=(3, 3), strides=(2, 2), name='pool3', padding="same")(x04)

    x06 = fire_module(x05, fire_id=4, squeeze=32, expand=128)
    x07 = fire_module(x06, fire_id=5, squeeze=32, expand=128)
    x08 = MaxPooling2D(pool_size=(3, 3), strides=(2, 2), name='pool5', padding="same")(x07)

    x09 = fire_module(x08, fire_id=6, squeeze=48, expand=192)
    x10 = fire_module(x09, fire_id=7, squeeze=48, expand=192)
    x11 = fire_module(x10, fire_id=8, squeeze=64, expand=256)
    x12 = fire_module(x11, fire_id=9, squeeze=64, expand=256)

    if dropout != 0.0:
        x12 = Dropout(dropout)(x12)

    up1 = concatenate([
        Conv2DTranspose(192, deconv_ksize, strides=(1, 1), padding='same')(x12),
        x10,
    ], axis=channel_axis)
    up1 = fire_module(up1, fire_id=10, squeeze=48, expand=192)

    up2 = concatenate([
        Conv2DTranspose(128, deconv_ksize, strides=(1, 1), padding='same')(up1),
        x08,
    ], axis=channel_axis)
    up2 = fire_module(up2, fire_id=11, squeeze=32, expand=128)

    up3 = concatenate([
        Conv2DTranspose(64, deconv_ksize, strides=(2, 2), padding='same')(up2),
        x05,
    ], axis=channel_axis)
    up3 = fire_module(up3, fire_id=12, squeeze=16, expand=64)

    up4 = concatenate([
        Conv2DTranspose(32, deconv_ksize, strides=(2, 2), padding='same')(up3),
        x02,
    ], axis=channel_axis)
    up4 = fire_module(up4, fire_id=13, squeeze=16, expand=32)
    up4 = UpSampling2D(size=(2, 2))(up4)

    x = concatenate([up4, x01], axis=channel_axis)
    x = Conv2D(64, (3, 3), strides=(1, 1), padding='same', activation='relu')(x)
    x = UpSampling2D(size=(2, 2))(x)
    x = Conv2D(num_classes, (1, 1), activation=activation)(x)
    model = Model(inputs, x)
    #model.summary()
    model.compile(optimizer=Adam(lr = 1e-4), loss=binary_crossentropy, metrics = ['accuracy',dice_coef,jacard,tf.keras.metrics.MeanIoU(num_classes=2),AUC(name='auc'),tf.keras.metrics.Precision(), tf.keras.metrics.Recall()])                                                                                
    return model

# %% [markdown]
# ## Random Search

# %%
input_path        = "/content/drive/MyDrive/png_data"
output_path       = "/content/drive/MyDrive/data/random_search"
test_path         = "/content/drive/MyDrive/png_data/train" # you have to split your data train and test  

n_iteration       = 10
n_augmentation    = 85
epoch             = 6

input_height      = 608
input_width       = 704
base_sample_count = 20
exclusion_list = ['.ipynb_checkpoints','combinations','test']

# %%
def random_search(input_path, output_path, test_path, n_iteration, n_augmentation, base_sample_count, epoch, input_height, input_width, exclusion_list):
  
  max_index = 0
  list_of_picked_augs = []
  dice_coefs = []
  aucs = []
  accuracies = []
  aug_list = os.listdir(input_path)
  
  print("Merge and Train :\n\n")
  for i in range(n_iteration):
    
    augmentations=[]
    exclude = exclusion_list
    
    os.mkdir(output_path + "/{}".format(i))
    new_output_path = output_path + "/{}".format(i)
    
    for m,n in enumerate(range(n_augmentation)):
      aug2=[i for i in aug_list if i not in augmentations and i not in exclude]
      random_aug=random.choice(aug2)
      augmentations.append(random_aug)
    
    print(f"Picked augmentations for {i}th iteration: ")
    print(augmentations)
    print('\n')
    list_of_picked_augs.append(augmentations)
    merge_augmentations(input_path, new_output_path, augmentations)
    print('------------------------------------------------------------------------------')

    print(f'Training for {i}th choices:\n')
    os.mkdir(output_path+'/'+str(i)+'/logs')
    os.mkdir(output_path+'/'+str(i)+'/checkpoints')
    
    LOG_PATH        = output_path+'/'+str(i)+'/logs'
    CKPTS_PATH      = output_path+'/'+str(i)+'/checkpoints'

    data_gen_args = dict()
    train_generator = trainGenerator(2, output_path + '/' + str(i), 'images','labels', data_gen_args, save_to_dir = None, target_size=(input_height,input_width))
    test_generator = testGenerator2(2, test_path, 'images','labels', data_gen_args, save_to_dir = None, target_size=(input_height,input_width))

    model = SqueezeUNet(inputs=Input((input_height, input_width, 1)))
    model_checkpoint = ModelCheckpoint(CKPTS_PATH + "/squeezeunet.hdf5", monitor='loss',verbose=1, save_best_only=True)
    model_history = model.fit_generator(train_generator,steps_per_epoch=n_augmentation*base_sample_count//2,epochs=epoch,callbacks=[model_checkpoint],
                                        validation_data=test_generator, validation_steps=len(os.listdir(test_path + '/images'))//2)

    log_file = open(LOG_PATH + "/log.pkl", "wb")#history file
    pickle.dump(model_history.history, log_file)
    log_file.close()

    dice_coefs.append(model_history.history['val_dice_coef'][epoch-1])
    aucs.append(model_history.history['val_auc'][epoch-1])
    accuracies.append(model_history.history['val_accuracy'][epoch-1])



    del model
    gc.collect()
    print('------------------------------------------------------------------------------')

    for i,item in enumerate(aucs):
      print(f'For {i}th choices :\t{item}')
      if item > aucs[max_index]:
        max_index = i
    
    print('------------------------------------------------------------------------------')
    print(f'Best Result for now occured {max_index}th choices and it is :\t{aucs[max_index]}, \nwith accuracy:\t{accuracies[max_index]}, \nwith dice coef:\t{dice_coefs[max_index]} \nPicked Augmentations :\n{list_of_picked_augs[max_index]}')
    print('--------------------------------------------------------------------------------------------------------------------------------------------------')

# %%
random_search(input_path, output_path, test_path, n_iteration, n_augmentation, base_sample_count, epoch, input_height, input_width, exclusion_list)
# Out:
# Merge and Train :
#
#
# Picked augmentations for 0th iteration:
# ['shifty_100_180', 'rotation300', 'eq_hist', 'shearY', 'shearX_90', 'gamma_corr05_rotation300', 'dropout010', 'album_heavy180', 'album_medium', 'white_noise10_90', 'style_transfer', 'flipping1_rotat60', 'zoom_out08_rotat330', 'album_optical90', 'rotation90', 'flipping0_rotat180', 'blurring5_270', 'shifty_-100', 'flipping0_rotat150', 'blurring3', 'zoom_out08_rotat150', 'album_random_crop3', 'album_optical270', 'zoom_out07', 'gamma_corr05_rotation120', 'shiftx_-100_180', 'shearing03', 'zoom_out08_rotat30', 'flipping1_rotat270', 'flipping1_rotat180', 'dropout010_180', 'album_optical180', 'dropout010_270', 'shifty_-100_90', 'shifty_100', 'dropout010_90', 'rotation150', 'flipping0_rotat210', 'rotation60', 'album_elastic', 'sharpen_270', 'zoom_out08_rotat300', 'gamma_corr05_rotation240', 'shiftx_-100_270', 'sharpen_90', 'shifty_100_90', 'rotation30', 'flipping0_rotat330', 'album_heavy', 'flipping1', 'album_random_crop4', 'flipping0_rotat30', 'rotation210', 'dropout005', 'rotation270', 'zoom_out08_rotat180', 'style_transfer_90', 'gamma_corr05_rotation60', 'album_random_crop', 'album_elastic180', 'shearY_90', 'gamma_corr05_rotation30', 'shifty_-100_270', 'rotation180', 'rotation120', 'gamma_corr05_rotation330', 'shearY_270', 'shiftx_100_180', 'sharpen_180', 'white_noise10', 'shearX', 'shiftx_100_270', 'flipping1_rotat90', 'flipping1_rotat300', 'jpeg_compression25', 'shearX_270', 'jpeg_compression75', 'white_noise', 'zoom_out08_rotat120', 'blurring5_90', 'flipping1_rotat240', 'flipping1_rotat210', 'gamma_corr05_rotation270', 'flipping0', 'album_grid_dist180']
#
#
# shifty_100_180 folder has been merged...
# Number of images in output: 20
# rotation300 folder has been merged...
# Number of images in output: 40
# eq_hist folder has been merged...
# Number of images in output: 60
# shearY folder has been merged...
# Number of images in output: 80
# shearX_90 folder has been merged...
# Number of images in output: 100
# gamma_corr05_rotation300 folder has been merged...
# Number of images in output: 120
# dropout010 folder has been merged...
# Number of images in output: 140
# album_heavy180 folder has been merged...
# Number of images in output: 160
# album_medium folder has been merged...
# Number of images in output: 180
# white_noise10_90 folder has been merged...
# Number of images in output: 200
# style_transfer folder has been merged...
# Number of images in output: 220
# flipping1_rotat60 folder has been merged...
# Number of images in output: 240
# zoom_out08_rotat330 folder has been merged...
# Number of images in output: 260
# album_optical90 folder has been merged...
# Number of images in output: 280
# rotation90 folder has been merged...
# Number of images in output: 300
# flipping0_rotat180 folder has been merged...
# Number of images in output: 320
# blurring5_270 folder has been merged...
# Number of images in output: 340
# shifty_-100 folder has been merged...
# Number of images in output: 360
# flipping0_rotat150 folder has been merged...
# Number of images in output: 380
# blurring3 folder has been merged...
# Number of images in output: 400
# zoom_out08_rotat150 folder has been merged...
# Number of images in output: 420
# album_random_crop3 folder has been merged...
# Number of images in output: 440
# album_optical270 folder has been merged...
# Number of images in output: 460
# zoom_out07 folder has been merged...
# Number of images in output: 480
# gamma_corr05_rotation120 folder has been merged...
# Number of images in output: 500
# shiftx_-100_180 folder has been merged...
# Number of images in output: 520
# shearing03 folder has been merged...
# Number of images in output: 540
# zoom_out08_rotat30 folder has been merged...
# Number of images in output: 560
# flipping1_rotat270 folder has been merged...
# Number of images in output: 580
# flipping1_rotat180 folder has been merged...
# Number of images in output: 600
# dropout010_180 folder has been merged...
# Number of images in output: 620
# album_optical180 folder has been merged...
# Number of images in output: 640
# dropout010_270 folder has been merged...
# Number of images in output: 660
# shifty_-100_90 folder has been merged...
# Number of images in output: 680
# shifty_100 folder has been merged...
# Number of images in output: 700
# dropout010_90 folder has been merged...
# Number of images in output: 720
# rotation150 folder has been merged...
# Number of images in output: 740
# flipping0_rotat210 folder has been merged...
# Number of images in output: 760
# rotation60 folder has been merged...
# Number of images in output: 780
# album_elastic folder has been merged...
# Number of images in output: 800
# sharpen_270 folder has been merged...
# Number of images in output: 820
# zoom_out08_rotat300 folder has been merged...
# Number of images in output: 840
# gamma_corr05_rotation240 folder has been merged...
# Number of images in output: 860
# shiftx_-100_270 folder has been merged...
# Number of images in output: 880
# sharpen_90 folder has been merged...
# Number of images in output: 900
# shifty_100_90 folder has been merged...
# Number of images in output: 920
# rotation30 folder has been merged...
# Number of images in output: 940
# flipping0_rotat330 folder has been merged...
# Number of images in output: 960
# album_heavy folder has been merged...
# Number of images in output: 980
# flipping1 folder has been merged...
# Number of images in output: 1000
# album_random_crop4 folder has been merged...
# Number of images in output: 1020
# flipping0_rotat30 folder has been merged...
# Number of images in output: 1040
# rotation210 folder has been merged...
# Number of images in output: 1060
# dropout005 folder has been merged...
# Number of images in output: 1080
# rotation270 folder has been merged...
# Number of images in output: 1100
# zoom_out08_rotat180 folder has been merged...
# Number of images in output: 1120
# style_transfer_90 folder has been merged...
# Number of images in output: 1140
# gamma_corr05_rotation60 folder has been merged...
# Number of images in output: 1160
# album_random_crop folder has been merged...
# Number of images in output: 1180
# album_elastic180 folder has been merged...
# Number of images in output: 1200
# shearY_90 folder has been merged...
# Number of images in output: 1220
# gamma_corr05_rotation30 folder has been merged...
# Number of images in output: 1240
# shifty_-100_270 folder has been merged...
# Number of images in output: 1260
# rotation180 folder has been merged...
# Number of images in output: 1280
# rotation120 folder has been merged...
# Number of images in output: 1300
# gamma_corr05_rotation330 folder has been merged...
# Number of images in output: 1320
# shearY_270 folder has been merged...
# Number of images in output: 1340
# shiftx_100_180 folder has been merged...
# Number of images in output: 1360
# sharpen_180 folder has been merged...
# Number of images in output: 1380
# white_noise10 folder has been merged...
# Number of images in output: 1400
# shearX folder has been merged...
# Number of images in output: 1420
# shiftx_100_270 folder has been merged...
# Number of images in output: 1440
# flipping1_rotat90 folder has been merged...
# Number of images in output: 1460
# flipping1_rotat300 folder has been merged...
# Number of images in output: 1480
# jpeg_compression25 folder has been merged...
# Number of images in output: 1500
# shearX_270 folder has been merged...
# Number of images in output: 1520
# jpeg_compression75 folder has been merged...
# Number of images in output: 1540
# white_noise folder has been merged...
# Number of images in output: 1560
# zoom_out08_rotat120 folder has been merged...
# Number of images in output: 1580
# blurring5_90 folder has been merged...
# Number of images in output: 1600
# flipping1_rotat240 folder has been merged...
# Number of images in output: 1620
# flipping1_rotat210 folder has been merged...
# Number of images in output: 1640
# gamma_corr05_rotation270 folder has been merged...
# Number of images in output: 1660
# flipping0 folder has been merged...
# Number of images in output: 1680
# album_grid_dist180 folder has been merged...
# Number of images in output: 1700
# Merging is done successfully!
# ------------------------------------------------------------------------------
# Training for 0th choices:
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/training.py:1844: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   warnings.warn('`Model.fit_generator` is deprecated and '
# Found 1700 images belonging to 1 classes.
# Found 1700 images belonging to 1 classes.
# Epoch 1/6
# 850/850 [==============================] - ETA: 0s - loss: 0.2551 - accuracy: 0.9071 - dice_coef: 0.2363 - jacard: 0.1369 - mean_io_u_14: 0.4545 - auc: 0.8033 - precision_14: 0.4304 - recall_14: 0.0974Found 20 images belonging to 1 classes.
# Found 20 images belonging to 1 classes.
# 850/850 [==============================] - 150s 172ms/step - loss: 0.2550 - accuracy: 0.9071 - dice_coef: 0.2364 - jacard: 0.1369 - mean_io_u_14: 0.4545 - auc: 0.8034 - precision_14: 0.4307 - recall_14: 0.0976 - val_loss: 0.1628 - val_accuracy: 0.9386 - val_dice_coef: 0.4509 - val_jacard: 0.2917 - val_mean_io_u_14: 0.4569 - val_auc: 0.9281 - val_precision_14: 0.7041 - val_recall_14: 0.4971
#
# Epoch 00001: loss improved from inf to 0.21533, saving model to /content/drive/MyDrive/data/random_search/0/checkpoints/squeezeunet.hdf5
# Epoch 2/6
# 850/850 [==============================] - 148s 174ms/step - loss: 0.1781 - accuracy: 0.9331 - dice_coef: 0.4305 - jacard: 0.2770 - mean_io_u_14: 0.4543 - auc: 0.9166 - precision_14: 0.7124 - recall_14: 0.4490 - val_loss: 0.1453 - val_accuracy: 0.9452 - val_dice_coef: 0.4850 - val_jacard: 0.3206 - val_mean_io_u_14: 0.4565 - val_auc: 0.9453 - val_precision_14: 0.8088 - val_recall_14: 0.4845
#
# Epoch 00002: loss improved from 0.21533 to 0.17289, saving model to /content/drive/MyDrive/data/random_search/0/checkpoints/squeezeunet.hdf5
# Epoch 3/6
# 850/850 [==============================] - 148s 175ms/step - loss: 0.1660 - accuracy: 0.9387 - dice_coef: 0.4683 - jacard: 0.3095 - mean_io_u_14: 0.4552 - auc: 0.9254 - precision_14: 0.7402 - recall_14: 0.4867 - val_loss: 0.1590 - val_accuracy: 0.9415 - val_dice_coef: 0.5231 - val_jacard: 0.3545 - val_mean_io_u_14: 0.4573 - val_auc: 0.9280 - val_precision_14: 0.6873 - val_recall_14: 0.5785
#
# Epoch 00003: loss improved from 0.17289 to 0.16482, saving model to /content/drive/MyDrive/data/random_search/0/checkpoints/squeezeunet.hdf5
# Epoch 4/6
# 850/850 [==============================] - 149s 175ms/step - loss: 0.1529 - accuracy: 0.9430 - dice_coef: 0.5146 - jacard: 0.3494 - mean_io_u_14: 0.4546 - auc: 0.9386 - precision_14: 0.7602 - recall_14: 0.5429 - val_loss: 0.1673 - val_accuracy: 0.9426 - val_dice_coef: 0.4810 - val_jacard: 0.3176 - val_mean_io_u_14: 0.4577 - val_auc: 0.9377 - val_precision_14: 0.8883 - val_recall_14: 0.3688
#
# Epoch 00004: loss improved from 0.16482 to 0.15271, saving model to /content/drive/MyDrive/data/random_search/0/checkpoints/squeezeunet.hdf5
# Epoch 5/6
# 850/850 [==============================] - 149s 175ms/step - loss: 0.1489 - accuracy: 0.9445 - dice_coef: 0.5321 - jacard: 0.3660 - mean_io_u_14: 0.4541 - auc: 0.9427 - precision_14: 0.7739 - recall_14: 0.5589 - val_loss: 0.1326 - val_accuracy: 0.9512 - val_dice_coef: 0.5191 - val_jacard: 0.3511 - val_mean_io_u_14: 0.4576 - val_auc: 0.9528 - val_precision_14: 0.8345 - val_recall_14: 0.5287
#
# Epoch 00005: loss improved from 0.15271 to 0.14564, saving model to /content/drive/MyDrive/data/random_search/0/checkpoints/squeezeunet.hdf5
# Epoch 6/6
# 850/850 [==============================] - 149s 175ms/step - loss: 0.1402 - accuracy: 0.9476 - dice_coef: 0.5537 - jacard: 0.3859 - mean_io_u_14: 0.4548 - auc: 0.9488 - precision_14: 0.7821 - recall_14: 0.5817 - val_loss: 0.1292 - val_accuracy: 0.9513 - val_dice_coef: 0.5565 - val_jacard: 0.3863 - val_mean_io_u_14: 0.4562 - val_auc: 0.9578 - val_precision_14: 0.7969 - val_recall_14: 0.5969
#
# Epoch 00006: loss improved from 0.14564 to 0.14068, saving model to /content/drive/MyDrive/data/random_search/0/checkpoints/squeezeunet.hdf5
# ------------------------------------------------------------------------------
# For 0th choices :	0.9577560424804688
# ------------------------------------------------------------------------------
# Best Result for now occured 0th choices and it is :	0.9577560424804688,
# with accuracy:	0.9513459205627441,
# with dice coef:	0.5565141439437866
# Picked Augmentations :
# ['shifty_100_180', 'rotation300', 'eq_hist', 'shearY', 'shearX_90', 'gamma_corr05_rotation300', 'dropout010', 'album_heavy180', 'album_medium', 'white_noise10_90', 'style_transfer', 'flipping1_rotat60', 'zoom_out08_rotat330', 'album_optical90', 'rotation90', 'flipping0_rotat180', 'blurring5_270', 'shifty_-100', 'flipping0_rotat150', 'blurring3', 'zoom_out08_rotat150', 'album_random_crop3', 'album_optical270', 'zoom_out07', 'gamma_corr05_rotation120', 'shiftx_-100_180', 'shearing03', 'zoom_out08_rotat30', 'flipping1_rotat270', 'flipping1_rotat180', 'dropout010_180', 'album_optical180', 'dropout010_270', 'shifty_-100_90', 'shifty_100', 'dropout010_90', 'rotation150', 'flipping0_rotat210', 'rotation60', 'album_elastic', 'sharpen_270', 'zoom_out08_rotat300', 'gamma_corr05_rotation240', 'shiftx_-100_270', 'sharpen_90', 'shifty_100_90', 'rotation30', 'flipping0_rotat330', 'album_heavy', 'flipping1', 'album_random_crop4', 'flipping0_rotat30', 'rotation210', 'dropout005', 'rotation270', 'zoom_out08_rotat180', 'style_transfer_90', 'gamma_corr05_rotation60', 'album_random_crop', 'album_elastic180', 'shearY_90', 'gamma_corr05_rotation30', 'shifty_-100_270', 'rotation180', 'rotation120', 'gamma_corr05_rotation330', 'shearY_270', 'shiftx_100_180', 'sharpen_180', 'white_noise10', 'shearX', 'shiftx_100_270', 'flipping1_rotat90', 'flipping1_rotat300', 'jpeg_compression25', 'shearX_270', 'jpeg_compression75', 'white_noise', 'zoom_out08_rotat120', 'blurring5_90', 'flipping1_rotat240', 'flipping1_rotat210', 'gamma_corr05_rotation270', 'flipping0', 'album_grid_dist180']
# --------------------------------------------------------------------------------------------------------------------------------------------------
# Picked augmentations for 1th iteration:
# ['dropout010', 'album_heavy270', 'rotation150', 'zoom_out08_rotat210', 'album_random_crop', 'rotation120', 'flipping1_rotat210', 'blurring3', 'zoom_out07', 'flipping1_rotat60', 'shearY_90', 'white_noise10', 'train', 'jpeg_compression75', 'zoom_out08_rotat60', 'style_transfer_180', 'flipping1_rotat180', 'shifty_100', 'shearX_90', 'album_optical90', 'album_medium', 'album_grid_dist180', 'album_heavy', 'zoom_out08_rotat150', 'album_heavy180', 'album_elastic90', 'shiftx_100', 'style_transfer_90', 'shifty_-100_180', 'dropout010_180', 'gamma_corr05_rotation120', 'album_optical180', 'zoom_out08_rotat270', 'rotation60', 'zoom_out08_rotat180', 'white_noise', 'gamma_corr05_rotation90', 'shiftx_100_90', 'album_elastic', 'album_medium90', 'rotation210', 'blurring5_180', 'flipping0_rotat300', 'flipping1_rotat240', 'album_random_crop4', 'rotation90', 'contrast', 'shearX', 'album_random_crop3', 'zoom_out08_rotat30', 'gamma_corr05_rotation150', 'rotation300', 'dropout010_90', 'shearY_270', 'gamma_corr05_rotation180', 'flipping0_rotat210', 'white_noise10_180', 'jpeg_compression25', 'white_noise10_90', 'gamma_corr05_rotation270', 'flipping0_rotat270', 'shearY', 'blurring5_270', 'album_optical', 'flipping1', 'jpeg_compression50', 'album_medium270', 'rotation270', 'blurring5_90', 'zoom_out08_rotat330', 'shearX_270', 'shifty_-100_270', 'flipping0_rotat120', 'white_noise10_270', 'shiftx_-100_90', 'zoom_out08_rotat90', 'shearY_180', 'blurring5', 'rotation180', 'gamma_correction20', 'shiftx_-100', 'flipping1_rotat150', 'shifty_100_270', 'style_transfer_270', 'shiftx_-100_270']
#
#
# dropout010 folder has been merged...
# Number of images in output: 20
# album_heavy270 folder has been merged...
# Number of images in output: 40
# rotation150 folder has been merged...
# Number of images in output: 60
# zoom_out08_rotat210 folder has been merged...
# Number of images in output: 80
# album_random_crop folder has been merged...
# Number of images in output: 100
# rotation120 folder has been merged...
# Number of images in output: 120
# flipping1_rotat210 folder has been merged...
# Number of images in output: 140
# blurring3 folder has been merged...
# Number of images in output: 160
# zoom_out07 folder has been merged...
# Number of images in output: 180
# flipping1_rotat60 folder has been merged...
# Number of images in output: 200
# shearY_90 folder has been merged...
# Number of images in output: 220
# white_noise10 folder has been merged...
# Number of images in output: 240
# train folder has been merged...
# Number of images in output: 260
# jpeg_compression75 folder has been merged...
# Number of images in output: 280
# zoom_out08_rotat60 folder has been merged...
# Number of images in output: 300
# style_transfer_180 folder has been merged...
# Number of images in output: 320
# flipping1_rotat180 folder has been merged...
# Number of images in output: 340
# shifty_100 folder has been merged...
# Number of images in output: 360
# shearX_90 folder has been merged...
# Number of images in output: 380
# album_optical90 folder has been merged...
# Number of images in output: 400
# album_medium folder has been merged...
# Number of images in output: 420
# album_grid_dist180 folder has been merged...
# Number of images in output: 440
# album_heavy folder has been merged...
# Number of images in output: 460
# zoom_out08_rotat150 folder has been merged...
# Number of images in output: 480
# album_heavy180 folder has been merged...
# Number of images in output: 500
# album_elastic90 folder has been merged...
# Number of images in output: 520
# shiftx_100 folder has been merged...
# Number of images in output: 540
# style_transfer_90 folder has been merged...
# Number of images in output: 560
# shifty_-100_180 folder has been merged...
# Number of images in output: 580
# dropout010_180 folder has been merged...
# Number of images in output: 600
# gamma_corr05_rotation120 folder has been merged...
# Number of images in output: 620
# album_optical180 folder has been merged...
# Number of images in output: 640
# zoom_out08_rotat270 folder has been merged...
# Number of images in output: 660
# rotation60 folder has been merged...
# Number of images in output: 680
# zoom_out08_rotat180 folder has been merged...
# Number of images in output: 700
# white_noise folder has been merged...
# Number of images in output: 720
# gamma_corr05_rotation90 folder has been merged...
# Number of images in output: 740
# shiftx_100_90 folder has been merged...
# Number of images in output: 760
# album_elastic folder has been merged...
# Number of images in output: 780
# album_medium90 folder has been merged...
# Number of images in output: 800
# rotation210 folder has been merged...
# Number of images in output: 820
# blurring5_180 folder has been merged...
# Number of images in output: 840
# flipping0_rotat300 folder has been merged...
# Number of images in output: 860
# flipping1_rotat240 folder has been merged...
# Number of images in output: 880
# album_random_crop4 folder has been merged...
# Number of images in output: 900
# rotation90 folder has been merged...
# Number of images in output: 920
# contrast folder has been merged...
# Number of images in output: 940
# shearX folder has been merged...
# Number of images in output: 960
# album_random_crop3 folder has been merged...
# Number of images in output: 980
# zoom_out08_rotat30 folder has been merged...
# Number of images in output: 1000
# gamma_corr05_rotation150 folder has been merged...
# Number of images in output: 1020
# rotation300 folder has been merged...
# Number of images in output: 1040
# dropout010_90 folder has been merged...
# Number of images in output: 1060
# shearY_270 folder has been merged...
# Number of images in output: 1080
# gamma_corr05_rotation180 folder has been merged...
# Number of images in output: 1100
# flipping0_rotat210 folder has been merged...
# Number of images in output: 1120
# white_noise10_180 folder has been merged...
# Number of images in output: 1140
# jpeg_compression25 folder has been merged...
# Number of images in output: 1160
# white_noise10_90 folder has been merged...
# Number of images in output: 1180
# gamma_corr05_rotation270 folder has been merged...
# Number of images in output: 1200
# flipping0_rotat270 folder has been merged...
# Number of images in output: 1220
# shearY folder has been merged...
# Number of images in output: 1240
# blurring5_270 folder has been merged...
# Number of images in output: 1260
# album_optical folder has been merged...
# Number of images in output: 1280
# flipping1 folder has been merged...
# Number of images in output: 1300
# jpeg_compression50 folder has been merged...
# Number of images in output: 1320
# album_medium270 folder has been merged...
# Number of images in output: 1340
# rotation270 folder has been merged...
# Number of images in output: 1360
# blurring5_90 folder has been merged...
# Number of images in output: 1380
# zoom_out08_rotat330 folder has been merged...
# Number of images in output: 1400
# shearX_270 folder has been merged...
# Number of images in output: 1420
# shifty_-100_270 folder has been merged...
# Number of images in output: 1440
# flipping0_rotat120 folder has been merged...
# Number of images in output: 1460
# white_noise10_270 folder has been merged...
# Number of images in output: 1480
# shiftx_-100_90 folder has been merged...
# Number of images in output: 1500
# zoom_out08_rotat90 folder has been merged...
# Number of images in output: 1520
# shearY_180 folder has been merged...
# Number of images in output: 1540
# blurring5 folder has been merged...
# Number of images in output: 1560
# rotation180 folder has been merged...
# Number of images in output: 1580
# gamma_correction20 folder has been merged...
# Number of images in output: 1600
# shiftx_-100 folder has been merged...
# Number of images in output: 1620
# flipping1_rotat150 folder has been merged...
# Number of images in output: 1640
# shifty_100_270 folder has been merged...
# Number of images in output: 1660
# style_transfer_270 folder has been merged...
# Number of images in output: 1680
# shiftx_-100_270 folder has been merged...
# Number of images in output: 1700
# Merging is done successfully!
# ------------------------------------------------------------------------------
# Training for 1th choices:
#
# Found 1700 images belonging to 1 classes.
# Found 1700 images belonging to 1 classes.
# Epoch 1/6
# 850/850 [==============================] - ETA: 0s - loss: 0.2934 - accuracy: 0.8782 - dice_coef: 0.2229 - jacard: 0.1285 - mean_io_u_15: 0.4538 - auc: 0.7594 - precision_15: 0.3278 - recall_15: 0.1388Found 20 images belonging to 1 classes.
# Found 20 images belonging to 1 classes.
# 850/850 [==============================] - 150s 172ms/step - loss: 0.2933 - accuracy: 0.8782 - dice_coef: 0.2230 - jacard: 0.1285 - mean_io_u_15: 0.4538 - auc: 0.7595 - precision_15: 0.3281 - recall_15: 0.1390 - val_loss: 0.1792 - val_accuracy: 0.9279 - val_dice_coef: 0.3358 - val_jacard: 0.2023 - val_mean_io_u_15: 0.4569 - val_auc: 0.9205 - val_precision_15: 0.8061 - val_recall_15: 0.2157
#
# Epoch 00001: loss improved from inf to 0.22859, saving model to /content/drive/MyDrive/data/random_search/1/checkpoints/squeezeunet.hdf5
# Epoch 2/6
# 850/850 [==============================] - 148s 174ms/step - loss: 0.1818 - accuracy: 0.9321 - dice_coef: 0.4231 - jacard: 0.2705 - mean_io_u_15: 0.4542 - auc: 0.9121 - precision_15: 0.7085 - recall_15: 0.4393 - val_loss: 0.1570 - val_accuracy: 0.9418 - val_dice_coef: 0.4831 - val_jacard: 0.3192 - val_mean_io_u_15: 0.4565 - val_auc: 0.9310 - val_precision_15: 0.7370 - val_recall_15: 0.5144
#
# Epoch 00002: loss improved from 0.22859 to 0.17667, saving model to /content/drive/MyDrive/data/random_search/1/checkpoints/squeezeunet.hdf5
# Epoch 3/6
# 850/850 [==============================] - 149s 175ms/step - loss: 0.1662 - accuracy: 0.9384 - dice_coef: 0.4821 - jacard: 0.3198 - mean_io_u_15: 0.4540 - auc: 0.9280 - precision_15: 0.7406 - recall_15: 0.5079 - val_loss: 0.1660 - val_accuracy: 0.9399 - val_dice_coef: 0.4358 - val_jacard: 0.2793 - val_mean_io_u_15: 0.4573 - val_auc: 0.9170 - val_precision_15: 0.7612 - val_recall_15: 0.4326
#
# Epoch 00003: loss improved from 0.17667 to 0.16340, saving model to /content/drive/MyDrive/data/random_search/1/checkpoints/squeezeunet.hdf5
# Epoch 4/6
# 850/850 [==============================] - 149s 175ms/step - loss: 0.1559 - accuracy: 0.9420 - dice_coef: 0.5095 - jacard: 0.3443 - mean_io_u_15: 0.4545 - auc: 0.9361 - precision_15: 0.7528 - recall_15: 0.5402 - val_loss: 0.1336 - val_accuracy: 0.9490 - val_dice_coef: 0.5048 - val_jacard: 0.3381 - val_mean_io_u_15: 0.4577 - val_auc: 0.9549 - val_precision_15: 0.8452 - val_recall_15: 0.4870
#
# Epoch 00004: loss improved from 0.16340 to 0.15602, saving model to /content/drive/MyDrive/data/random_search/1/checkpoints/squeezeunet.hdf5
# Epoch 5/6
# 850/850 [==============================] - 149s 175ms/step - loss: 0.1497 - accuracy: 0.9441 - dice_coef: 0.5336 - jacard: 0.3662 - mean_io_u_15: 0.4541 - auc: 0.9424 - precision_15: 0.7651 - recall_15: 0.5649 - val_loss: 0.1265 - val_accuracy: 0.9530 - val_dice_coef: 0.5647 - val_jacard: 0.3938 - val_mean_io_u_15: 0.4576 - val_auc: 0.9559 - val_precision_15: 0.7889 - val_recall_15: 0.6083
#
# Epoch 00005: loss improved from 0.15602 to 0.14830, saving model to /content/drive/MyDrive/data/random_search/1/checkpoints/squeezeunet.hdf5
# Epoch 6/6
# 850/850 [==============================] - 149s 175ms/step - loss: 0.1433 - accuracy: 0.9465 - dice_coef: 0.5518 - jacard: 0.3833 - mean_io_u_15: 0.4541 - auc: 0.9472 - precision_15: 0.7757 - recall_15: 0.5856 - val_loss: 0.1299 - val_accuracy: 0.9503 - val_dice_coef: 0.5552 - val_jacard: 0.3847 - val_mean_io_u_15: 0.4562 - val_auc: 0.9575 - val_precision_15: 0.7833 - val_recall_15: 0.5980
#
# Epoch 00006: loss improved from 0.14830 to 0.14321, saving model to /content/drive/MyDrive/data/random_search/1/checkpoints/squeezeunet.hdf5
# ------------------------------------------------------------------------------
# For 0th choices :	0.9577560424804688
# For 1th choices :	0.9575195908546448
# ------------------------------------------------------------------------------
# Best Result for now occured 0th choices and it is :	0.9577560424804688,
# with accuracy:	0.9513459205627441,
# with dice coef:	0.5565141439437866
# Picked Augmentations :
# ['shifty_100_180', 'rotation300', 'eq_hist', 'shearY', 'shearX_90', 'gamma_corr05_rotation300', 'dropout010', 'album_heavy180', 'album_medium', 'white_noise10_90', 'style_transfer', 'flipping1_rotat60', 'zoom_out08_rotat330', 'album_optical90', 'rotation90', 'flipping0_rotat180', 'blurring5_270', 'shifty_-100', 'flipping0_rotat150', 'blurring3', 'zoom_out08_rotat150', 'album_random_crop3', 'album_optical270', 'zoom_out07', 'gamma_corr05_rotation120', 'shiftx_-100_180', 'shearing03', 'zoom_out08_rotat30', 'flipping1_rotat270', 'flipping1_rotat180', 'dropout010_180', 'album_optical180', 'dropout010_270', 'shifty_-100_90', 'shifty_100', 'dropout010_90', 'rotation150', 'flipping0_rotat210', 'rotation60', 'album_elastic', 'sharpen_270', 'zoom_out08_rotat300', 'gamma_corr05_rotation240', 'shiftx_-100_270', 'sharpen_90', 'shifty_100_90', 'rotation30', 'flipping0_rotat330', 'album_heavy', 'flipping1', 'album_random_crop4', 'flipping0_rotat30', 'rotation210', 'dropout005', 'rotation270', 'zoom_out08_rotat180', 'style_transfer_90', 'gamma_corr05_rotation60', 'album_random_crop', 'album_elastic180', 'shearY_90', 'gamma_corr05_rotation30', 'shifty_-100_270', 'rotation180', 'rotation120', 'gamma_corr05_rotation330', 'shearY_270', 'shiftx_100_180', 'sharpen_180', 'white_noise10', 'shearX', 'shiftx_100_270', 'flipping1_rotat90', 'flipping1_rotat300', 'jpeg_compression25', 'shearX_270', 'jpeg_compression75', 'white_noise', 'zoom_out08_rotat120', 'blurring5_90', 'flipping1_rotat240', 'flipping1_rotat210', 'gamma_corr05_rotation270', 'flipping0', 'album_grid_dist180']
# --------------------------------------------------------------------------------------------------------------------------------------------------
# Picked augmentations for 2th iteration:
# ['zoom_out08_rotat120', 'white_noise10_180', 'zoom_out08_rotat150', 'gamma_corr05_rotation120', 'jpeg_compression25', 'shiftx_100_90', 'jpeg_compression50', 'shifty_-100_270', 'gamma_correction15', 'white_noise10_90', 'album_grid_dist', 'rotation90', 'album_grid_dist180', 'shifty_-100_180', 'style_transfer_180', 'shiftx_-100_180', 'album_heavy270', 'gamma_correction05', 'flipping1_rotat300', 'album_random_crop3', 'flipping0', 'zoom_out08_rotat240', 'flipping1_rotat180', 'album_elastic180', 'flipping0_rotat240', 'blurring5', 'album_optical', 'zoom_out07', 'flipping0_rotat180', 'gamma_corr05', 'shifty_100_180', 'gamma_corr05_rotation270', 'album_optical180', 'rotation120', 'flipping1_rotat30', 'gamma_corr05_rotation60', 'blurring5_180', 'flipping0_rotat270', 'shiftx_100_270', 'shearY_90', 'rotation240', 'rotation180', 'shearing03', 'saturation05', 'album_optical270', 'album_heavy', 'rotation210', 'shiftx_-100', 'album_medium', 'shiftx_100', 'blurring5_270', 'flipping0_rotat330', 'shifty_-100_90', 'white_noise10_270', 'rotation60', 'white_noise', 'shiftx_-100_270', 'shearX_270', 'zoom_out08_rotat270', 'style_transfer_90', 'flipping1_rotat240', 'zoom_out08_rotat210', 'flipping1_rotat270', 'gamma_corr05_rotation30', 'rotation270', 'gamma_corr05_rotation210', 'album_medium180', 'flipping0_rotat120', 'shifty_-100', 'album_elastic90', 'sharpen_270', 'zoom_out08_rotat30', 'blurring5_90', 'flipping0_rotat210', 'zoom_out08_rotat90', 'shifty_100_90', 'contrast', 'album_medium270', 'flipping0_rotat300', 'sharpen_180', 'album_random_crop4', 'gamma_correction20', 'style_transfer_270', 'rotation330', 'gamma_corr05_rotation330']
#
#
# zoom_out08_rotat120 folder has been merged...
# Number of images in output: 20
# white_noise10_180 folder has been merged...
# Number of images in output: 40
# zoom_out08_rotat150 folder has been merged...
# Number of images in output: 60
# gamma_corr05_rotation120 folder has been merged...
# Number of images in output: 80
# jpeg_compression25 folder has been merged...
# Number of images in output: 100
# shiftx_100_90 folder has been merged...
# Number of images in output: 120
# jpeg_compression50 folder has been merged...
# Number of images in output: 140
# shifty_-100_270 folder has been merged...
# Number of images in output: 160
# gamma_correction15 folder has been merged...
# Number of images in output: 180
# white_noise10_90 folder has been merged...
# Number of images in output: 200
# album_grid_dist folder has been merged...
# Number of images in output: 220
# rotation90 folder has been merged...
# Number of images in output: 240
# album_grid_dist180 folder has been merged...
# Number of images in output: 260
# shifty_-100_180 folder has been merged...
# Number of images in output: 280
# style_transfer_180 folder has been merged...
# Number of images in output: 300
# shiftx_-100_180 folder has been merged...
# Number of images in output: 320
# album_heavy270 folder has been merged...
# Number of images in output: 340
# gamma_correction05 folder has been merged...
# Number of images in output: 360
# flipping1_rotat300 folder has been merged...
# Number of images in output: 380
# album_random_crop3 folder has been merged...
# Number of images in output: 400
# flipping0 folder has been merged...
# Number of images in output: 420
# zoom_out08_rotat240 folder has been merged...
# Number of images in output: 440
# flipping1_rotat180 folder has been merged...
# Number of images in output: 460
# album_elastic180 folder has been merged...
# Number of images in output: 480
# flipping0_rotat240 folder has been merged...
# Number of images in output: 500
# blurring5 folder has been merged...
# Number of images in output: 520
# album_optical folder has been merged...
# Number of images in output: 540
# zoom_out07 folder has been merged...
# Number of images in output: 560
# flipping0_rotat180 folder has been merged...
# Number of images in output: 580
# gamma_corr05 folder has been merged...
# Number of images in output: 600
# shifty_100_180 folder has been merged...
# Number of images in output: 620
# gamma_corr05_rotation270 folder has been merged...
# Number of images in output: 640
# album_optical180 folder has been merged...
# Number of images in output: 660
# rotation120 folder has been merged...
# Number of images in output: 680
# flipping1_rotat30 folder has been merged...
# Number of images in output: 700
# gamma_corr05_rotation60 folder has been merged...
# Number of images in output: 720
# blurring5_180 folder has been merged...
# Number of images in output: 740
# flipping0_rotat270 folder has been merged...
# Number of images in output: 760
# shiftx_100_270 folder has been merged...
# Number of images in output: 780
# shearY_90 folder has been merged...
# Number of images in output: 800
# rotation240 folder has been merged...
# Number of images in output: 820
# rotation180 folder has been merged...
# Number of images in output: 840
# shearing03 folder has been merged...
# Number of images in output: 860
# saturation05 folder has been merged...
# Number of images in output: 880
# album_optical270 folder has been merged...
# Number of images in output: 900
# album_heavy folder has been merged...
# Number of images in output: 920
# rotation210 folder has been merged...
# Number of images in output: 940
# shiftx_-100 folder has been merged...
# Number of images in output: 960
# album_medium folder has been merged...
# Number of images in output: 980
# shiftx_100 folder has been merged...
# Number of images in output: 1000
# blurring5_270 folder has been merged...
# Number of images in output: 1020
# flipping0_rotat330 folder has been merged...
# Number of images in output: 1040
# shifty_-100_90 folder has been merged...
# Number of images in output: 1060
# white_noise10_270 folder has been merged...
# Number of images in output: 1080
# rotation60 folder has been merged...
# Number of images in output: 1100
# white_noise folder has been merged...
# Number of images in output: 1120
# shiftx_-100_270 folder has been merged...
# Number of images in output: 1140
# shearX_270 folder has been merged...
# Number of images in output: 1160
# zoom_out08_rotat270 folder has been merged...
# Number of images in output: 1180
# style_transfer_90 folder has been merged...
# Number of images in output: 1200
# flipping1_rotat240 folder has been merged...
# Number of images in output: 1220
# zoom_out08_rotat210 folder has been merged...
# Number of images in output: 1240
# flipping1_rotat270 folder has been merged...
# Number of images in output: 1260
# gamma_corr05_rotation30 folder has been merged...
# Number of images in output: 1280
# rotation270 folder has been merged...
# Number of images in output: 1300
# gamma_corr05_rotation210 folder has been merged...
# Number of images in output: 1320
# album_medium180 folder has been merged...
# Number of images in output: 1340
# flipping0_rotat120 folder has been merged...
# Number of images in output: 1360
# shifty_-100 folder has been merged...
# Number of images in output: 1380
# album_elastic90 folder has been merged...
# Number of images in output: 1400
# sharpen_270 folder has been merged...
# Number of images in output: 1420
# zoom_out08_rotat30 folder has been merged...
# Number of images in output: 1440
# blurring5_90 folder has been merged...
# Number of images in output: 1460
# flipping0_rotat210 folder has been merged...
# Number of images in output: 1480
# zoom_out08_rotat90 folder has been merged...
# Number of images in output: 1500
# shifty_100_90 folder has been merged...
# Number of images in output: 1520
# contrast folder has been merged...
# Number of images in output: 1540
# album_medium270 folder has been merged...
# Number of images in output: 1560
# flipping0_rotat300 folder has been merged...
# Number of images in output: 1580
# sharpen_180 folder has been merged...
# Number of images in output: 1600
# album_random_crop4 folder has been merged...
# Number of images in output: 1620
# gamma_correction20 folder has been merged...
# Number of images in output: 1640
# style_transfer_270 folder has been merged...
# Number of images in output: 1660
# rotation330 folder has been merged...
# Number of images in output: 1680
# gamma_corr05_rotation330 folder has been merged...
# Number of images in output: 1700
# Merging is done successfully!
# ------------------------------------------------------------------------------
# Training for 2th choices:
#
# Found 1700 images belonging to 1 classes.
# Found 1700 images belonging to 1 classes.
# Epoch 1/6
# 850/850 [==============================] - ETA: 0s - loss: 0.2718 - accuracy: 0.8866 - dice_coef: 0.2435 - jacard: 0.1420 - mean_io_u_16: 0.4541 - auc: 0.7934 - precision_16: 0.3606 - recall_16: 0.1455Found 20 images belonging to 1 classes.
# Found 20 images belonging to 1 classes.
# 850/850 [==============================] - 153s 176ms/step - loss: 0.2718 - accuracy: 0.8866 - dice_coef: 0.2436 - jacard: 0.1420 - mean_io_u_16: 0.4541 - auc: 0.7935 - precision_16: 0.3609 - recall_16: 0.1457 - val_loss: 0.1711 - val_accuracy: 0.9350 - val_dice_coef: 0.4353 - val_jacard: 0.2787 - val_mean_io_u_16: 0.4569 - val_auc: 0.9270 - val_precision_16: 0.6438 - val_recall_16: 0.5513
#
# Epoch 00001: loss improved from inf to 0.21428, saving model to /content/drive/MyDrive/data/random_search/2/checkpoints/squeezeunet.hdf5
# Epoch 2/6
# 850/850 [==============================] - 150s 177ms/step - loss: 0.1707 - accuracy: 0.9357 - dice_coef: 0.4571 - jacard: 0.2975 - mean_io_u_16: 0.4545 - auc: 0.9237 - precision_16: 0.7192 - recall_16: 0.4830 - val_loss: 0.1417 - val_accuracy: 0.9467 - val_dice_coef: 0.5308 - val_jacard: 0.3617 - val_mean_io_u_16: 0.4565 - val_auc: 0.9461 - val_precision_16: 0.7518 - val_recall_16: 0.5785
#
# Epoch 00002: loss improved from 0.21428 to 0.16494, saving model to /content/drive/MyDrive/data/random_search/2/checkpoints/squeezeunet.hdf5
# Epoch 3/6
# 850/850 [==============================] - 151s 177ms/step - loss: 0.1545 - accuracy: 0.9422 - dice_coef: 0.5131 - jacard: 0.3466 - mean_io_u_16: 0.4546 - auc: 0.9372 - precision_16: 0.7484 - recall_16: 0.5470 - val_loss: 0.1327 - val_accuracy: 0.9504 - val_dice_coef: 0.5645 - val_jacard: 0.3935 - val_mean_io_u_16: 0.4573 - val_auc: 0.9516 - val_precision_16: 0.7870 - val_recall_16: 0.5753
#
# Epoch 00003: loss improved from 0.16494 to 0.14828, saving model to /content/drive/MyDrive/data/random_search/2/checkpoints/squeezeunet.hdf5
# Epoch 4/6
# 850/850 [==============================] - 151s 178ms/step - loss: 0.1432 - accuracy: 0.9461 - dice_coef: 0.5520 - jacard: 0.3823 - mean_io_u_16: 0.4541 - auc: 0.9478 - precision_16: 0.7686 - recall_16: 0.5902 - val_loss: 0.1230 - val_accuracy: 0.9533 - val_dice_coef: 0.5702 - val_jacard: 0.3992 - val_mean_io_u_16: 0.4577 - val_auc: 0.9602 - val_precision_16: 0.8332 - val_recall_16: 0.5603
#
# Epoch 00004: loss improved from 0.14828 to 0.14126, saving model to /content/drive/MyDrive/data/random_search/2/checkpoints/squeezeunet.hdf5
# Epoch 5/6
# 850/850 [==============================] - 150s 177ms/step - loss: 0.1335 - accuracy: 0.9497 - dice_coef: 0.5779 - jacard: 0.4071 - mean_io_u_16: 0.4547 - auc: 0.9541 - precision_16: 0.7826 - recall_16: 0.6156 - val_loss: 0.1235 - val_accuracy: 0.9530 - val_dice_coef: 0.5944 - val_jacard: 0.4233 - val_mean_io_u_16: 0.4576 - val_auc: 0.9642 - val_precision_16: 0.7178 - val_recall_16: 0.7344
#
# Epoch 00005: loss improved from 0.14126 to 0.13375, saving model to /content/drive/MyDrive/data/random_search/2/checkpoints/squeezeunet.hdf5
# Epoch 6/6
# 850/850 [==============================] - 151s 177ms/step - loss: 0.1278 - accuracy: 0.9517 - dice_coef: 0.5923 - jacard: 0.4215 - mean_io_u_16: 0.4551 - auc: 0.9577 - precision_16: 0.7875 - recall_16: 0.6329 - val_loss: 0.1221 - val_accuracy: 0.9531 - val_dice_coef: 0.5981 - val_jacard: 0.4271 - val_mean_io_u_16: 0.4562 - val_auc: 0.9639 - val_precision_16: 0.7469 - val_recall_16: 0.7032
#
# Epoch 00006: loss improved from 0.13375 to 0.12902, saving model to /content/drive/MyDrive/data/random_search/2/checkpoints/squeezeunet.hdf5
# ------------------------------------------------------------------------------
# For 0th choices :	0.9577560424804688
# For 1th choices :	0.9575195908546448
# For 2th choices :	0.9639248251914978
# ------------------------------------------------------------------------------
# Best Result for now occured 2th choices and it is :	0.9639248251914978,
# with accuracy:	0.953109085559845,
# with dice coef:	0.5980812311172485
# Picked Augmentations :
# ['zoom_out08_rotat120', 'white_noise10_180', 'zoom_out08_rotat150', 'gamma_corr05_rotation120', 'jpeg_compression25', 'shiftx_100_90', 'jpeg_compression50', 'shifty_-100_270', 'gamma_correction15', 'white_noise10_90', 'album_grid_dist', 'rotation90', 'album_grid_dist180', 'shifty_-100_180', 'style_transfer_180', 'shiftx_-100_180', 'album_heavy270', 'gamma_correction05', 'flipping1_rotat300', 'album_random_crop3', 'flipping0', 'zoom_out08_rotat240', 'flipping1_rotat180', 'album_elastic180', 'flipping0_rotat240', 'blurring5', 'album_optical', 'zoom_out07', 'flipping0_rotat180', 'gamma_corr05', 'shifty_100_180', 'gamma_corr05_rotation270', 'album_optical180', 'rotation120', 'flipping1_rotat30', 'gamma_corr05_rotation60', 'blurring5_180', 'flipping0_rotat270', 'shiftx_100_270', 'shearY_90', 'rotation240', 'rotation180', 'shearing03', 'saturation05', 'album_optical270', 'album_heavy', 'rotation210', 'shiftx_-100', 'album_medium', 'shiftx_100', 'blurring5_270', 'flipping0_rotat330', 'shifty_-100_90', 'white_noise10_270', 'rotation60', 'white_noise', 'shiftx_-100_270', 'shearX_270', 'zoom_out08_rotat270', 'style_transfer_90', 'flipping1_rotat240', 'zoom_out08_rotat210', 'flipping1_rotat270', 'gamma_corr05_rotation30', 'rotation270', 'gamma_corr05_rotation210', 'album_medium180', 'flipping0_rotat120', 'shifty_-100', 'album_elastic90', 'sharpen_270', 'zoom_out08_rotat30', 'blurring5_90', 'flipping0_rotat210', 'zoom_out08_rotat90', 'shifty_100_90', 'contrast', 'album_medium270', 'flipping0_rotat300', 'sharpen_180', 'album_random_crop4', 'gamma_correction20', 'style_transfer_270', 'rotation330', 'gamma_corr05_rotation330']
# --------------------------------------------------------------------------------------------------------------------------------------------------
# Picked augmentations for 3th iteration:
# ['gamma_corr05_rotation150', 'album_random_crop3', 'white_noise10_90', 'album_optical90', 'rotation210', 'flipping0_rotat330', 'flipping1_rotat210', 'album_medium180', 'shifty_-100', 'album_random_crop', 'blurring5_180', 'rotation120', 'gamma_correction15', 'gamma_corr05_rotation240', 'flipping0_rotat300', 'flipping1_rotat30', 'flipping0_rotat210', 'elastic', 'flipping0_rotat90', 'shearing03', 'zoom_out08_rotat300', 'rotation300', 'album_optical', 'album_medium', 'shiftx_-100', 'shearY_90', 'gamma_corr05_rotation180', 'eq_hist', 'flipping0_rotat60', 'album_medium270', 'album_heavy90', 'album_heavy', 'album_elastic90', 'blurring5_270', 'zoom_out08_rotat90', 'dropout010', 'album_random_crop4', 'sharpen', 'album_elastic180', 'contrast', 'shifty_-100_180', 'sharpen_90', 'flipping1', 'style_transfer_270', 'dropout010_270', 'rotation270', 'saturation05', 'flipping1_rotat330', 'album_grid_dist', 'gamma_corr05_rotation210', 'style_transfer', 'flipping0_rotat120', 'shiftx_-100_180', 'style_transfer_90', 'flipping1_rotat270', 'sharpen_270', 'shiftx_100', 'zoom_out08_rotat270', 'gamma_corr05_rotation330', 'gamma_correction05', 'white_noise10_270', 'zoom_out07', 'blurring5', 'album_optical180', 'blurring3', 'train', 'album_medium90', 'flipping0_rotat30', 'gamma_correction20', 'flipping0', 'album_random_crop2', 'jpeg_compression75', 'white_noise10', 'rotation30', 'gamma_corr05_rotation90', 'gamma_corr05_rotation120', 'style_transfer_180', 'shifty_100', 'zoom_out08_rotat210', 'shiftx_100_180', 'zoom_out08_rotat180', 'shifty_-100_90', 'flipping1_rotat180', 'rotation60', 'flipping1_rotat120']
#
#
# gamma_corr05_rotation150 folder has been merged...
# Number of images in output: 20
# album_random_crop3 folder has been merged...
# Number of images in output: 40
# white_noise10_90 folder has been merged...
# Number of images in output: 60
# album_optical90 folder has been merged...
# Number of images in output: 80
# rotation210 folder has been merged...
# Number of images in output: 100
# flipping0_rotat330 folder has been merged...
# Number of images in output: 120
# flipping1_rotat210 folder has been merged...
# Number of images in output: 140
# album_medium180 folder has been merged...
# Number of images in output: 160
# shifty_-100 folder has been merged...
# Number of images in output: 180
# album_random_crop folder has been merged...
# Number of images in output: 200
# blurring5_180 folder has been merged...
# Number of images in output: 220
# rotation120 folder has been merged...
# Number of images in output: 240
# gamma_correction15 folder has been merged...
# Number of images in output: 260
# gamma_corr05_rotation240 folder has been merged...
# Number of images in output: 280
# flipping0_rotat300 folder has been merged...
# Number of images in output: 300
# flipping1_rotat30 folder has been merged...
# Number of images in output: 320
# flipping0_rotat210 folder has been merged...
# Number of images in output: 340
# elastic folder has been merged...
# Number of images in output: 360
# flipping0_rotat90 folder has been merged...
# Number of images in output: 380
# shearing03 folder has been merged...
# Number of images in output: 400
# zoom_out08_rotat300 folder has been merged...
# Number of images in output: 420
# rotation300 folder has been merged...
# Number of images in output: 440
# album_optical folder has been merged...
# Number of images in output: 460
# album_medium folder has been merged...
# Number of images in output: 480
# shiftx_-100 folder has been merged...
# Number of images in output: 500
# shearY_90 folder has been merged...
# Number of images in output: 520
# gamma_corr05_rotation180 folder has been merged...
# Number of images in output: 540
# eq_hist folder has been merged...
# Number of images in output: 560
# flipping0_rotat60 folder has been merged...
# Number of images in output: 580
# album_medium270 folder has been merged...
# Number of images in output: 600
# album_heavy90 folder has been merged...
# Number of images in output: 620
# album_heavy folder has been merged...
# Number of images in output: 640
# album_elastic90 folder has been merged...
# Number of images in output: 660
# blurring5_270 folder has been merged...
# Number of images in output: 680
# zoom_out08_rotat90 folder has been merged...
# Number of images in output: 700
# dropout010 folder has been merged...
# Number of images in output: 720
# album_random_crop4 folder has been merged...
# Number of images in output: 740
# sharpen folder has been merged...
# Number of images in output: 760
# album_elastic180 folder has been merged...
# Number of images in output: 780
# contrast folder has been merged...
# Number of images in output: 800
# shifty_-100_180 folder has been merged...
# Number of images in output: 820
# sharpen_90 folder has been merged...
# Number of images in output: 840
# flipping1 folder has been merged...
# Number of images in output: 860
# style_transfer_270 folder has been merged...
# Number of images in output: 880
# dropout010_270 folder has been merged...
# Number of images in output: 900
# rotation270 folder has been merged...
# Number of images in output: 920
# saturation05 folder has been merged...
# Number of images in output: 940
# flipping1_rotat330 folder has been merged...
# Number of images in output: 960
# album_grid_dist folder has been merged...
# Number of images in output: 980
# gamma_corr05_rotation210 folder has been merged...
# Number of images in output: 1000
# style_transfer folder has been merged...
# Number of images in output: 1020
# flipping0_rotat120 folder has been merged...
# Number of images in output: 1040
# shiftx_-100_180 folder has been merged...
# Number of images in output: 1060
# style_transfer_90 folder has been merged...
# Number of images in output: 1080
# flipping1_rotat270 folder has been merged...
# Number of images in output: 1100
# sharpen_270 folder has been merged...
# Number of images in output: 1120
# shiftx_100 folder has been merged...
# Number of images in output: 1140
# zoom_out08_rotat270 folder has been merged...
# Number of images in output: 1160
# gamma_corr05_rotation330 folder has been merged...
# Number of images in output: 1180
# gamma_correction05 folder has been merged...
# Number of images in output: 1200
# ...
# shearX folder has been merged...
# Number of images in output: 1300
# rotation150 folder has been merged...
# Number of images in output: 1320
# jpeg_compression50 folder has been merged...
# Number of images in output: 1340
# flipping1_rotat270 folder has been merged...
# Number of images in output: 1360
# flipping0_rotat120 folder has been merged...
# Number of images in output: 1380
# gamma_corr05_rotation270 folder has been merged...
# Number of images in output: 1400
# dropout010_180 folder has been merged...
# Number of images in output: 1420
# shiftx_100 folder has been merged...
# Number of images in output: 1440
# shearY_270 folder has been merged...
# Number of images in output: 1460
# shearY_180 folder has been merged...
# Number of images in output: 1480
# shiftx_100_180 folder has been merged...
# Number of images in output: 1500
# flipping0_rotat270 folder has been merged...
# Number of images in output: 1520
# white_noise10_90 folder has been merged...
# Number of images in output: 1540
# album_medium90 folder has been merged...
# Number of images in output: 1560
# train folder has been merged...
# Number of images in output: 1580
# gamma_corr05_rotation60 folder has been merged...
# Number of images in output: 1600
# contrast folder has been merged...
# Number of images in output: 1620
# album_optical180 folder has been merged...
# Number of images in output: 1640
# album_elastic90 folder has been merged...
# Number of images in output: 1660
# dropout005 folder has been merged...
# Number of images in output: 1680
# shifty_-100_270 folder has been merged...
# Number of images in output: 1700
# Merging is done successfully!
# ------------------------------------------------------------------------------
# Training for 4th choices:
#
# Found 1700 images belonging to 1 classes.
# Found 1700 images belonging to 1 classes.
# Epoch 1/6
# 850/850 [==============================] - ETA: 0s - loss: 0.2627 - accuracy: 0.9045 - dice_coef: 0.2450 - jacard: 0.1441 - mean_io_u_18: 0.4539 - auc: 0.7894 - precision_18: 0.4603 - recall_18: 0.1437Found 20 images belonging to 1 classes.
# Found 20 images belonging to 1 classes.
# 850/850 [==============================] - 155s 178ms/step - loss: 0.2626 - accuracy: 0.9046 - dice_coef: 0.2451 - jacard: 0.1442 - mean_io_u_18: 0.4539 - auc: 0.7895 - precision_18: 0.4606 - recall_18: 0.1438 - val_loss: 0.1593 - val_accuracy: 0.9399 - val_dice_coef: 0.4755 - val_jacard: 0.3124 - val_mean_io_u_18: 0.4569 - val_auc: 0.9310 - val_precision_18: 0.6869 - val_recall_18: 0.5573
#
# Epoch 00001: loss improved from inf to 0.20931, saving model to /content/drive/MyDrive/data/random_search/4/checkpoints/squeezeunet.hdf5
# Epoch 2/6
# 850/850 [==============================] - 152s 178ms/step - loss: 0.1682 - accuracy: 0.9374 - dice_coef: 0.4722 - jacard: 0.3109 - mean_io_u_18: 0.4542 - auc: 0.9262 - precision_18: 0.7360 - recall_18: 0.4936 - val_loss: 0.1370 - val_accuracy: 0.9489 - val_dice_coef: 0.5269 - val_jacard: 0.3579 - val_mean_io_u_18: 0.4565 - val_auc: 0.9525 - val_precision_18: 0.7595 - val_recall_18: 0.6032
#
# Epoch 00002: loss improved from 0.20931 to 0.16432, saving model to /content/drive/MyDrive/data/random_search/4/checkpoints/squeezeunet.hdf5
# Epoch 3/6
# 850/850 [==============================] - 152s 179ms/step - loss: 0.1543 - accuracy: 0.9427 - dice_coef: 0.5128 - jacard: 0.3474 - mean_io_u_18: 0.4547 - auc: 0.9372 - precision_18: 0.7602 - recall_18: 0.5375 - val_loss: 0.1311 - val_accuracy: 0.9501 - val_dice_coef: 0.5577 - val_jacard: 0.3871 - val_mean_io_u_18: 0.4573 - val_auc: 0.9549 - val_precision_18: 0.8102 - val_recall_18: 0.5441
#
# Epoch 00003: loss improved from 0.16432 to 0.15124, saving model to /content/drive/MyDrive/data/random_search/4/checkpoints/squeezeunet.hdf5
# Epoch 4/6
# 850/850 [==============================] - 152s 179ms/step - loss: 0.1438 - accuracy: 0.9461 - dice_coef: 0.5483 - jacard: 0.3798 - mean_io_u_18: 0.4544 - auc: 0.9467 - precision_18: 0.7732 - recall_18: 0.5786 - val_loss: 0.1175 - val_accuracy: 0.9555 - val_dice_coef: 0.5867 - val_jacard: 0.4154 - val_mean_io_u_18: 0.4577 - val_auc: 0.9635 - val_precision_18: 0.7918 - val_recall_18: 0.6431
#
# Epoch 00004: loss improved from 0.15124 to 0.14270, saving model to /content/drive/MyDrive/data/random_search/4/checkpoints/squeezeunet.hdf5
# Epoch 5/6
# 850/850 [==============================] - 152s 179ms/step - loss: 0.1378 - accuracy: 0.9483 - dice_coef: 0.5662 - jacard: 0.3969 - mean_io_u_18: 0.4545 - auc: 0.9511 - precision_18: 0.7824 - recall_18: 0.5980 - val_loss: 0.1171 - val_accuracy: 0.9562 - val_dice_coef: 0.5915 - val_jacard: 0.4204 - val_mean_io_u_18: 0.4576 - val_auc: 0.9658 - val_precision_18: 0.7703 - val_recall_18: 0.6887
#
# Epoch 00005: loss improved from 0.14270 to 0.13672, saving model to /content/drive/MyDrive/data/random_search/4/checkpoints/squeezeunet.hdf5
# Epoch 6/6
# 850/850 [==============================] - 152s 179ms/step - loss: 0.1295 - accuracy: 0.9513 - dice_coef: 0.5856 - jacard: 0.4159 - mean_io_u_18: 0.4552 - auc: 0.9565 - precision_18: 0.7910 - recall_18: 0.6206 - val_loss: 0.1179 - val_accuracy: 0.9541 - val_dice_coef: 0.6179 - val_jacard: 0.4475 - val_mean_io_u_18: 0.4562 - val_auc: 0.9655 - val_precision_18: 0.7662 - val_recall_18: 0.6846
#
# Epoch 00006: loss improved from 0.13672 to 0.13190, saving model to /content/drive/MyDrive/data/random_search/4/checkpoints/squeezeunet.hdf5
# ------------------------------------------------------------------------------
# For 0th choices :	0.9577560424804688
# For 1th choices :	0.9575195908546448
# For 2th choices :	0.9639248251914978
# For 3th choices :	0.9603990316390991
# For 4th choices :	0.9654582738876343
# ------------------------------------------------------------------------------
# Best Result for now occured 4th choices and it is :	0.9654582738876343,
# with accuracy:	0.9540555477142334,
# with dice coef:	0.6178518533706665
# Picked Augmentations :
# ['flipping1_rotat240', 'album_elastic', 'gamma_corr05_rotation300', 'white_noise10_270', 'shiftx_-100_180', 'shifty_100_270', 'rotation90', 'sharpen_270', 'album_medium270', 'gamma_corr05_rotation330', 'style_transfer_270', 'zoom_out08_rotat30', 'shifty_100', 'flipping0_rotat60', 'saturation05', 'album_optical', 'flipping1_rotat90', 'flipping0_rotat30', 'shearX_90', 'flipping1', 'rotation180', 'white_noise', 'flipping1_rotat120', 'flipping0_rotat330', 'shifty_-100_90', 'album_grid_dist180', 'flipping1_rotat150', 'zoom_out08_rotat150', 'flipping0_rotat90', 'shearing03', 'album_random_crop4', 'flipping0_rotat180', 'shifty_100_180', 'style_transfer_180', 'sharpen', 'flipping1_rotat330', 'zoom_out08_rotat60', 'gamma_correction05', 'gamma_correction20', 'shiftx_-100_270', 'flipping0_rotat150', 'gamma_corr05', 'gamma_corr05_rotation90', 'flipping0_rotat300', 'gamma_corr05_rotation180', 'dropout010_270', 'blurring5_180', 'zoom_out08_rotat120', 'style_transfer_90', 'shiftx_100_90', 'rotation270', 'shearX_180', 'flipping1_rotat210', 'blurring5', 'zoom_out08_rotat240', 'album_heavy', 'gamma_corr05_rotation30', 'album_grid_dist270', 'album_optical270', 'sharpen_180', 'sharpen_90', 'shiftx_-100_90', 'dropout010', 'zoom_out08_rotat300', 'shearX', 'rotation150', 'jpeg_compression50', 'flipping1_rotat270', 'flipping0_rotat120', 'gamma_corr05_rotation270', 'dropout010_180', 'shiftx_100', 'shearY_270', 'shearY_180', 'shiftx_100_180', 'flipping0_rotat270', 'white_noise10_90', 'album_medium90', 'train', 'gamma_corr05_rotation60', 'contrast', 'album_optical180', 'album_elastic90', 'dropout005', 'shifty_-100_270']
# --------------------------------------------------------------------------------------------------------------------------------------------------
# Picked augmentations for 5th iteration:
# ['dropout010', 'contrast', 'zoom_out08_rotat30', 'shearY_90', 'shiftx_-100_270', 'eq_hist', 'shifty_-100_180', 'gamma_corr05_rotation150', 'shifty_100_270', 'album_grid_dist270', 'album_medium', 'sharpen_180', 'style_transfer_270', 'album_grid_dist180', 'rotation300', 'album_grid_dist', 'flipping0_rotat60', 'flipping1_rotat300', 'zoom_out08_rotat240', 'rotation120', 'flipping0_rotat300', 'flipping1_rotat60', 'gamma_correction15', 'gamma_corr05_rotation120', 'flipping0_rotat330', 'album_heavy', 'album_heavy180', 'flipping1_rotat330', 'zoom_out08_rotat90', 'shearY_180', 'album_medium90', 'dropout010_270', 'shifty_-100_90', 'flipping1_rotat270', 'blurring5_180', 'zoom_out08_rotat120', 'blurring5', 'shifty_100_90', 'rotation60', 'sharpen', 'style_transfer_180', 'flipping1_rotat120', 'shiftx_100_180', 'gamma_corr05_rotation330', 'album_medium270', 'album_medium180', 'saturation05', 'rotation270', 'shifty_100', 'white_noise10', 'album_random_crop', 'shifty_100_180', 'flipping1_rotat240', 'zoom_out08_rotat210', 'sharpen_270', 'shearX_180', 'white_noise', 'shiftx_100_90', 'rotation240', 'jpeg_compression75', 'rotation150', 'album_heavy270', 'gamma_corr05_rotation60', 'style_transfer', 'flipping0', 'flipping1_rotat30', 'flipping1_rotat90', 'flipping1_rotat210', 'rotation210', 'blurring3', 'gamma_corr05_rotation210', 'style_transfer_90', 'flipping0_rotat210', 'shearX_270', 'shiftx_100_270', 'zoom_out08_rotat300', 'flipping0_rotat270', 'dropout010_180', 'rotation330', 'sharpen_90', 'album_elastic90', 'gamma_corr05_rotation90', 'album_optical270', 'album_random_crop2', 'album_random_crop4']
#
#
# dropout010 folder has been merged...
# Number of images in output: 20
# contrast folder has been merged...
# Number of images in output: 40
# zoom_out08_rotat30 folder has been merged...
# Number of images in output: 60
# shearY_90 folder has been merged...
# Number of images in output: 80
# shiftx_-100_270 folder has been merged...
# Number of images in output: 100
# eq_hist folder has been merged...
# Number of images in output: 120
# shifty_-100_180 folder has been merged...
# Number of images in output: 140
# gamma_corr05_rotation150 folder has been merged...
# Number of images in output: 160
# shifty_100_270 folder has been merged...
# Number of images in output: 180
# album_grid_dist270 folder has been merged...
# Number of images in output: 200
# album_medium folder has been merged...
# Number of images in output: 220
# sharpen_180 folder has been merged...
# Number of images in output: 240
# style_transfer_270 folder has been merged...
# Number of images in output: 260
# album_grid_dist180 folder has been merged...
# Number of images in output: 280
# rotation300 folder has been merged...
# Number of images in output: 300
# album_grid_dist folder has been merged...
# Number of images in output: 320
# flipping0_rotat60 folder has been merged...
# Number of images in output: 340
# flipping1_rotat300 folder has been merged...
# Number of images in output: 360
# zoom_out08_rotat240 folder has been merged...
# Number of images in output: 380
# rotation120 folder has been merged...
# Number of images in output: 400
# flipping0_rotat300 folder has been merged...
# Number of images in output: 420
# flipping1_rotat60 folder has been merged...
# Number of images in output: 440
# gamma_correction15 folder has been merged...
# Number of images in output: 460
# gamma_corr05_rotation120 folder has been merged...
# Number of images in output: 480
# flipping0_rotat330 folder has been merged...
# Number of images in output: 500
# album_heavy folder has been merged...
# Number of images in output: 520
# album_heavy180 folder has been merged...
# Number of images in output: 540
# flipping1_rotat330 folder has been merged...
# Number of images in output: 560
# zoom_out08_rotat90 folder has been merged...
# Number of images in output: 580
# shearY_180 folder has been merged...
# Number of images in output: 600
# album_medium90 folder has been merged...
# Number of images in output: 620
# dropout010_270 folder has been merged...
# Number of images in output: 640
# shifty_-100_90 folder has been merged...
# Number of images in output: 660
# flipping1_rotat270 folder has been merged...
# Number of images in output: 680
# blurring5_180 folder has been merged...
# Number of images in output: 700
# zoom_out08_rotat120 folder has been merged...
# Number of images in output: 720
# blurring5 folder has been merged...
# Number of images in output: 740
# shifty_100_90 folder has been merged...
# Number of images in output: 760
# rotation60 folder has been merged...
# Number of images in output: 780
# sharpen folder has been merged...
# Number of images in output: 800
# style_transfer_180 folder has been merged...
# Number of images in output: 820
# flipping1_rotat120 folder has been merged...
# Number of images in output: 840
# shiftx_100_180 folder has been merged...
# Number of images in output: 860
# gamma_corr05_rotation330 folder has been merged...
# Number of images in output: 880
# album_medium270 folder has been merged...
# Number of images in output: 900
# album_medium180 folder has been merged...
# Number of images in output: 920
# saturation05 folder has been merged...
# Number of images in output: 940
# rotation270 folder has been merged...
# Number of images in output: 960
# shifty_100 folder has been merged...
# Number of images in output: 980
# white_noise10 folder has been merged...
# Number of images in output: 1000
# album_random_crop folder has been merged...
# Number of images in output: 1020
# shifty_100_180 folder has been merged...
# Number of images in output: 1040
# flipping1_rotat240 folder has been merged...
# Number of images in output: 1060
# zoom_out08_rotat210 folder has been merged...
# Number of images in output: 1080
# sharpen_270 folder has been merged...
# Number of images in output: 1100
# shearX_180 folder has been merged...
# Number of images in output: 1120
# white_noise folder has been merged...
# Number of images in output: 1140
# shiftx_100_90 folder has been merged...
# Number of images in output: 1160
# rotation240 folder has been merged...
# Number of images in output: 1180
# jpeg_compression75 folder has been merged...
# Number of images in output: 1200
# rotation150 folder has been merged...
# Number of images in output: 1220
# album_heavy270 folder has been merged...
# Number of images in output: 1240
# gamma_corr05_rotation60 folder has been merged...
# Number of images in output: 1260
# style_transfer folder has been merged...
# Number of images in output: 1280
# flipping0 folder has been merged...
# Number of images in output: 1300
# flipping1_rotat30 folder has been merged...
# Number of images in output: 1320
# flipping1_rotat90 folder has been merged...
# Number of images in output: 1340
# flipping1_rotat210 folder has been merged...
# Number of images in output: 1360
# rotation210 folder has been merged...
# Number of images in output: 1380
# blurring3 folder has been merged...
# Number of images in output: 1400
# gamma_corr05_rotation210 folder has been merged...
# Number of images in output: 1420
# style_transfer_90 folder has been merged...
# Number of images in output: 1440
# flipping0_rotat210 folder has been merged...
# Number of images in output: 1460
# shearX_270 folder has been merged...
# Number of images in output: 1480
# shiftx_100_270 folder has been merged...
# Number of images in output: 1500
# zoom_out08_rotat300 folder has been merged...
# Number of images in output: 1520
# flipping0_rotat270 folder has been merged...
# Number of images in output: 1540
# dropout010_180 folder has been merged...
# Number of images in output: 1560
# rotation330 folder has been merged...
# Number of images in output: 1580
# sharpen_90 folder has been merged...
# Number of images in output: 1600
# album_elastic90 folder has been merged...
# Number of images in output: 1620
# gamma_corr05_rotation90 folder has been merged...
# Number of images in output: 1640
# album_optical270 folder has been merged...
# Number of images in output: 1660
# album_random_crop2 folder has been merged...
# Number of images in output: 1680
# album_random_crop4 folder has been merged...
# Number of images in output: 1700
# Merging is done successfully!
# ------------------------------------------------------------------------------
# Training for 5th choices:
#
# Found 1700 images belonging to 1 classes.
# Found 1700 images belonging to 1 classes.
# Epoch 1/6
# 391/850 [============>.................] - ETA: 1:20 - loss: 0.2912 - accuracy: 0.9025 - dice_coef: 0.1766 - jacard: 0.0979 - mean_io_u_19: 0.4534 - auc: 0.7261 - precision_19: 0.2996 - recall_19: 0.0319
